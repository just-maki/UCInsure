# %% [markdown]
# import dependecies

# %%
# %pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %% [markdown]
# reading the data from the csv files and storing them in dataframes

# %%
Fimaset = pd.read_csv('Fimaset.csv')
noaaset = pd.read_csv('noaaset.csv')
# Out:
# /var/folders/5n/kg6d24jn7jd7pxbgc23tzv5w0000gn/T/ipykernel_91396/3046691200.py:1: DtypeWarning: Columns (0: elevationCertificateIndicator, 1: nfipCommunityNumberCurrent, 2: reportedZipCode) have mixed types. Specify dtype option on import or set low_memory=False.
#   Fimaset = pd.read_csv('Fimaset.csv')

# %%
Fimaset.info()
print(Fimaset.describe())
print(Fimaset.columns)
print("nulls in Fimaset:")
Fimaset.isnull().sum().sort_values(ascending=False)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2719735 entries, 0 to 2719734
# Data columns (total 73 columns):
#  #   Column                                      Dtype
# ---  ------                                      -----
#  0   agricultureStructureIndicator               int64
#  1   asOfDate                                    str
#  2   basementEnclosureCrawlspaceType             float64
#  3   policyCount                                 int64
#  4   crsClassificationCode                       float64
#  5   dateOfLoss                                  str
#  6   elevatedBuildingIndicator                   int64
#  7   elevationCertificateIndicator               object
#  8   elevationDifference                         float64
#  9   baseFloodElevation                          float64
#  10  ratedFloodZone                              str
#  11  houseWorship                                int64
#  12  locationOfContents                          float64
# ...

# %%
noaaset.info()
print(noaaset.describe())
print(noaaset.columns)
print("nulls in noaaset:")
noaaset.isnull().sum().sort_values(ascending=False)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 6 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Name                                           258 non-null    str
#  1   Disaster                                       258 non-null    str
#  2   Begin Date                                     258 non-null    int64
#  3   End Date                                       258 non-null    int64
#  4   Total CPI-Adjusted Cost (Millions of Dollars)  258 non-null    float64
#  5   Deaths                                         258 non-null    int64
# dtypes: float64(1), int64(3), str(2)
# memory usage: 12.2 KB
#          Begin Date      End Date  \
# count  2.580000e+02  2.580000e+02
# mean   2.005421e+07  2.005443e+07
# std    1.101692e+05  1.100144e+05
# min    1.980041e+07  1.980042e+07
# 25%    1.997047e+07  1.997292e+07
# ...
